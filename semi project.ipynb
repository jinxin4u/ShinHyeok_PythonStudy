# %%
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np

import random
import sys
import io
import re
# Out:
# Using TensorFlow backend.
# C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')

path = '현진건-운수좋은날.txt'
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()

text = re.sub(r'<.*>', '', text)
text = re.sub(r'\n', ' ', text)
text = re.sub(r' +', ' ', text)

print('corpus length:', len(text))
# Out:
# corpus length: 10207

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 693

# %%
maxlen = 40
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# nb sequences: 3389
# Vectorization...

# %%
print('Build model...')
model = Sequential()
model.add(LSTM(1024, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=0.001))
# Out:
# Build model...
# WARNING:tensorflow:From C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    print('\n----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
#     for diversity in [0.2, 0.5, 1.0, 1.2]:
#         print('----- diversity:', diversity)

    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    print('----- Generating with seed: "' + sentence + '"')
    sys.stdout.write(generated)

    for i in range(400):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, 0.5)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y, batch_size=128, epochs=60, callbacks=[print_callback])
# Out:
# WARNING:tensorflow:From C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\ICT01_11\.conda\envs\tf_test\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Epoch 1/60
# 3389/3389 [==============================] - 28s 8ms/step - loss: 5.1940
#
# ----- Generating text after Epoch: 0
# ----- Generating with seed: "지 가잔 말을 들은 순간에 경련적으로 떠는 손, 유달리 큼직한 눈, 울 "
# 지 가잔 말을 들은 순간에 경련적으로 떠는 손, 유달리 큼직한 눈, 울 는              ,              .          지         고  는       지                ,                                     , ,                                        .       게              을        고  이        어                     지              지하       이더                                    의                     는 지                     를          .       ,   는   내        고             어
# Epoch 2/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 4.5798
#
# ----- Generating text after Epoch: 1
# ----- Generating with seed: "그는 병이란 놈에게 약을 주어 보내면 재미를 붙여서 자꾸 온다는 자기의 "
# 그는 병이란 놈에게 약을 주어 보내면 재미를 붙여서 자꾸 온다는 자기의       ”                  그      그                        라   ,           아           .         을                        .  선     신   만 는         의                                                                                                                                     이  .                                             .             사     .                                리
# Epoch 3/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 4.5249
#
# ----- Generating text after Epoch: 2
# ----- Generating with seed: " 돈이 얼마나 괜찮고 괴로운 것인 줄 절실히 느끼었다. 정거장을 떠나는 "
#  돈이 얼마나 괜찮고 괴로운 것인 줄 절실히 느끼었다. 정거장을 떠나는 나    았     을  을      거       ,               로      하 리    이이            는         의        리                         도    는    의       이  라         는 이        지        가       , 보  보    리           이   , 이           을     게            이   , 는 대  이  운   가  이    비    .                    ,              를        로                     다           .    리                            .              는
# Epoch 4/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 4.4014
#
# ----- Generating text after Epoch: 3
# ----- Generating with seed: "가 그저 오기가 안됐데 그려, 그래 전차 정류장에서 어름어름하며 손님 하"
# 가 그저 오기가 안됐데 그려, 그래 전차 정류장에서 어름어름하며 손님 하  가       그  .       도  일  소   .             리   .  는 는 전기   다   이     .  이 이  은   어  하   라 하 이 이    다    을  , 는  이  이 이 . 하 다   이   이         음 으  나    이  는 이 이  니      이  가  이는  이 하고 이  첨   하 이  로  는  이   시 는 다하 그 .  은   서   고  도   는  이     을  남    시을 이이 지   아     이 다 음  에 에  는  리  듯  이이 이   이    이  이 이 라  다   이  이 자            이  일이  깨이 이다였, 이  는  이 이 는  이   고  하  서 이 시  까      그 로 은  이  하는  는
# Epoch 5/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 4.2081
#
# ----- Generating text after Epoch: 4
# ----- Generating with seed: " 뚱뚱보는 말라깽이를 보는 말맡에 부르짖었다. 그 목소리는 몸짓과 딴판으"
#  뚱뚱보는 말라깽이를 보는 말맡에 부르짖었다. 그 목소리는 몸짓과 딴판으  아가 내 이  아 한 그 를   를  그 이  나 로 눈 전  이 누 니  가 , 선고 바하가 아  은 그 다. 내 아가 그 가 제 기 피  이  였. 있마. 보 은다. 그하 니 그 아 라  이 하  가 그 아고 그  다  그 을 그 그 연 다  이 그 지  마다 ” 이 이  기 지  이 이 그    기 그  미 . 기기  첨 다   아 . “내 들  가 . 나에 아이 가 마 , 그 “고 . 였지 ” .  가 전 이 한 니 고 그이 내 비  기 . 김 고 . 나 이  이  다  이 그   니  년    다  …한 어은 집 여  움   다가  하는  같가 이 를 보 바 말  기가 그 다는 그 다  매   다니 ” 상   무아어  이 었은 ” 그 다  이 다 하는 았를  운  아이 정 흘  가 . 이 가 기
# Epoch 6/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 4.0426
#
# ----- Generating text after Epoch: 5
# ----- Generating with seed: "음을 지쳐나가는 스케이트 모양으로 미끄러져가는 듯하였다. 언땅에 비가 내"
# 음을 지쳐나가는 스케이트 모양으로 미끄러져가는 듯하였다. 언땅에 비가 내 손다. 그 이 전리 하   는 그기 시 말  가 다죽 다 이 이  였 라 로 이 오리 미었 한 이 웃 , 오이 는 손리 내다. 대  의 꼬는  그   은 나첨이 오는 하에 한 에  이  여서 대하  듯       에 이 거 일 이 나 근 잔 말 이 로삼 미 근  이  는 불 어 이 오에 랑지  의 이 전 에 . 에 사 한  으   는 전리로 “라  한 눈 는 그 에 로 다가 오는  리 는 보의  이 전 들 에 의 전 이 사대  치 이 이 눈의 걸 한 , 오 를 내서 놓 에  리 로 말네  하는 그 로  리다  앞에  는  의의 들고  의 에 에 이 그 전 거   을 왜의 흘 이 의 하 의 주 로 말력 는 말는 하리  이 이 거  하 에 내 에 거서 하서  어이 말이 이 은 . 두 에 에 하고 그  오한 하
# Epoch 7/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 3.8979
#
# ----- Generating text after Epoch: 6
# ----- Generating with seed: "첨지도 이 불길한 침묵을 짐작했는지도 모른다. 그렇지 않으면 대문에 들어"
# 첨지도 이 불길한 침묵을 짐작했는지도 모른다. 그렇지 않으면 대문에 들어장 서 추  어어 여 그 리고  은 르 아 .은 하고 사 오 로 치 에 바 지 이 오 이 . 왔 듯 여어어 은 정어에 이 눈이 . 지 이 , 오 에 한 같 로 먹은 듯가 같었서 라 가 김 이 김 떨로  여는 려 은 울을 그 다 다. 그 로을 어어 하어. 정 재다. 그 ‘하이 이 마 다는 이 적 였다. 하리 하을 내 하 행 이 같 마 게에 내 가 에 손 내에다. 더 오시 인를 인 하가 하는 서 양을 물 도 치 가 사 하는  마 에어, 그 전에  이 였다. 그 누의 내는 전어에 소 에 게 이 그 지 소 돈 두 그 구한 그 이 에는 이 다. 그 같이 마는 오 에 왔  시 이  이 어는 구 을 그 라 네 서에 그 이 이 하기을 그 나어이 같거은 푼은 그 이 아이 다은 바 나… 이 다자 이  었다. 그 나 로 . 이
# Epoch 8/60
# 3389/3389 [==============================] - 28s 8ms/step - loss: 3.7971
#
# ----- Generating text after Epoch: 7
# ----- Generating with seed: "게 술이 취해 가지고 이 진 땅에 어찌 가노 하고, 길 가는 사람이 걱정"
# 게 술이 취해 가지고 이 진 땅에 어찌 가노 하고, 길 가는 사람이 걱정 하도 제 하을 이 에 이 잔 이 … 오하가 오이 내리 지는 제 에 이 근 이  고 게 거 도 바었다. 그 이 게을 그게 말리 다. “하고 말은 김첨지는 “이 하첨지는 하시다. 그 구을 붙에에 말을 인이 치이 , 하는 사리에 이 오첨지 , 쿨 로 하이 하 에 전하였다. “하아 놈는 이 다고 소리에 눈에 이 말에 . 이 하고 말이 거이 머이 내이  고 이 하하다. 얼리 가 말러다. 김첨지 이 하고 의 하고  첨고  상고 불 하는 . 하다. “하고 말리에 손 에 은 안 다 로 하기  게 이 게 지 지 에 하이 , 하가에 그 이 는 이 하 가  고 내가 그 하이 나려가 하였다. “하다. “이 의 말 거을 . 하고 바 거어  얼에 한 하이 다었. 그 그 에 로 에 지 성 하는 비음 도 이 에 없는 무리에 그 의 없
# Epoch 9/60
# 3389/3389 [==============================] - 29s 8ms/step - loss: 3.6014
#
# ----- Generating text after Epoch: 8
# ----- Generating with seed: "고는 돌아선다. 김첨지는 어랍시요 하고 물러섰다. 전차가 왔다. 김첨지는"
# 고는 돌아선다. 김첨지는 어랍시요 하고 물러섰다. 전차가 왔다. 김첨지는 그 그 , 말 않 으 하 , 오 라 지 다고 정 그 같 도 보 지 먹리다. “라지 말을 듯 이 사 의 그 하고 그 오 가 지 은 그 사을 그 그 주 보 기 여 친 지 그 그 에 사 서 그 오 그 지 모 일 사 이 그 그 그 그 웃는 . “의 말을 이 이 늘 이 시 그 지 듯 하고 제 그의 이 라 질 하을 벌테 정 비리. 그 한 전 말 하고  육 그 김첨지 “ 아 못 … 말은 이 하고  기고 그 그 듯 서 전 그 비 하 다. “ 그 이 나 나 그 그 오 에 울 오 그 지 전 하 생 얼 하 하고 정 가 치 ? 손 오 말 이 오 그 을 말 하리 . 그 질 느을 그 돈 도 그 울 못 하, 사 하은 울 그 사, 벌 그 나 그 그 그 말 라 지 사 하을 다 그 나는 이 하리였다. 그 그 이 나는. 그 울 지 말첨지
# Epoch 10/60
# 3389/3389 [==============================] - 28s 8ms/step - loss: 3.5681
#
# ----- Generating text after Epoch: 9
# ----- Generating with seed: "다고 하는 듯하였다. 그럴 즈음에 마침 길가 선술집에서 친구 치삼이가 나"
# 다고 하는 듯하였다. 그럴 즈음에 마침 길가 선술집에서 친구 치삼이가 나 하을 . “을을 말이 다. 돈 훔 을 시 신 치 그 소 비 높 다. 그 하을 말 다리  이  에 이 사 락 . 전 찔 을 나 지 있 다. 아 집을 사 하리. “자컸 있을 . 그 말을 . 그 병을 나 하기다. “ 오을 대고 적 같을 . 하 다을 맞 하을 한 그 놓을 . 대 비을 이 사 을 정 을 거 다.  증이 다 다. 그 그 생 다. . 그 을 라 다. 나 근 하고 . 그 얼을 . 하 이 김 에 전 ? 거 내 ? 다 이 다 없 다 거 여 메 말 ? 놈 그 있 같 다. 이 일 고 터 거을 . 오 을 말 다을 같 이 . 듯 하을 . 그 을 속 다. . 하고 을 병 잔 하고 . 왜 김첨지는 인 세을 집 그 하 다. 같리 을 없을 . 이 그 듯 가 그 사을 붙을 다을 이 차 하을 . 오 을 하 다. 이 그 말을
# Epoch 11/60
# 3389/3389 [==============================] - 28s 8ms/step - loss: 3.4101
#
# ----- Generating text after Epoch: 10
# ----- Generating with seed: "좋으니까 그런 요행이 또 한번 없으리라고 누가 보증하랴. 꼬리를 굴리는 "
# 좋으니까 그런 요행이 또 한번 없으리라고 누가 보증하랴. 꼬리를 굴리는 그 하는 눈리에 내 김 잔 질 잔 전 비 내 勢 하였다. 그 전 김첨지는 그리 리고 그 전 보 더 하 질 도 붙이  마의 내리  첨지는 그 사음 전은 손에 그리 이 나 오기  “ 기 미 ? 거 하는  마장 고 그이  그 다  이  고 그 한 … 내 운 사 주 없다. “아래 김첨지는 “리장 들이  어간 내놈  이  가  왜 가 들어서 마아  내리 일 그 채리러 아 그 김첨지는 하아. “이 을 떠 금 는 오다. “이  이 며 오고  음리  인 하 진 전 눈 가 오 못 아 들 하가 손리 가 하고 그 비 세 떨 나 그 없 은 하는 . 보 에 대리나 바어 야 하고 하지  들그 내니에 나 지는 치기를 울리아 그 그 거리에 그 오 보는  리으  내가  남에 다리  리리 일 간 은 잠기  가 전 나 울 이 친 얼 하 족
# Epoch 12/60
# 3389/3389 [==============================] - 28s 8ms/step - loss: 3.2367
#
# ----- Generating text after Epoch: 11
# ----- Generating with seed: " 켕기었다. 앞집 마나님한테서 부르러 왔을 제 병인은 그 뼈만 남은 얼굴"
#  켕기었다. 앞집 마나님한테서 부르러 왔을 제 병인은 그 뼈만 남은 얼굴 이 이 한 이  이 그 한 이 하고 손이 하였다. 그걸 비고고 물은 같은 없을 그똥 이똥 이 울고 소리  운 이 하였다. 그 고 두이 소아은 같은 . 에는 대래 소리고 어이 하였다. 그 새고 김첨지는 말굴 하고 얼어 이 한 손리이 많은 이 나이 그 이 한 나어 이 에 한 하였다. 그일 김첨지는 눈은 울은 그 한 ? 하였다. 왜 하고 나 은 하고 같을 이묘 그러다. 하음 어고 이 하였다. 그밥 이 이 전은 나가 이 이 목을 소리 게 하였다. 그가 김첨지는 말운 이었 .  이 비이 그  시은 울한 이 이 소리 한  같은 붙증 이 하였다. 그뜻 이고 대우 이았, 있” 하고 김첨지는 눈았 이 나, 이 다는 남이 못하고 주어 그리 요, 이 말 이 하였다. 그럴 이고 두은 이은 소리 이 나 질 어먹 전우 이 하였다.
# Epoch 13/60
# 3389/3389 [==============================] - 29s 9ms/step - loss: 3.1007
#
# ----- Generating text after Epoch: 12
# ----- Generating with seed: "한 때문이다. 그때도 김첨지가 오래간만에 돈을 얻어서 좁쌀 한 되와 십 "
# 한 때문이다. 그때도 김첨지가 오래간만에 돈을 얻어서 좁쌀 한 되와 십 전십 전에에 한 하를 소리에 어 에를 못에에 그 한리한는 그 전의지의 대에 하을 걸 에에 걸한 어내에 한 한 을을 대에 얼에에 눈에에 그삼에 오어에 그는 오찌에 한 에 들었에 기에에 한 은 내는 대에에마서 그 거에에 거어에의 대에 제 그 한 나에에 한에 마을 기생에 한 한 에리에 주에 기은에 한 오을 의 오기에 제에 기을 벌에에 들어, 그의에 에에 마었다. 그 그는 의에로 대에에 기에 의 손에 기찌에 하였다. 그 하의 어어운한 한에에 그 에 한 를 한 이의 기에에 거을 왜을 왜 울 지의 기에에에 어 어자을 대에에 김첨지의 대에에 어를 같을 웃어에 그 한 일시에 에에 비을 대 에 지는 기기에는 한 그의 내에 을 신져 추,에, 그 나의 의 를 그를 전에에 그 한 잔에에 집에 그의에게 하는 마기에게 오인한 내에에
# Epoch 14/60
# 3389/3389 [==============================] - 29s 8ms/step - loss: 2.9587
#
# ----- Generating text after Epoch: 13
# ----- Generating with seed: " 눌러 곱빼기 한 잔을 또 마셨다. 김첨지의 눈은 벌써 개개 풀리기 시작"
#  눌러 곱빼기 한 잔을 또 마셨다. 김첨지의 눈은 벌써 개개 풀리기 시작 이 운다. 또 대이 그을 듯이 도 지의 듯이 도 왔은 가이 그 지이 말이 , 지이 같은 .을 내가 말이 비려 비을 이이 , 붙이  이 비다. 그 나을 말이 이 질가 의 나 있를 못 다. 그 기고 추은 이 말다. 이 하고 울무며 시이 . 못이 나은 나, 이 다이 그 하였다. 오가 가고 김첨지는 말인 자요 내가 나을 바수 보이 는 다. 더이 보이 같이 , 친 지이 게 인이 , 라이 놓은 내을 내가 매이 그 손이 사기를 , 전거가 이 김첨지는 보르가 수 보가 차 얼고 내가 가 나말을 이 수 말는 이 말을 내이 있이 불이 내이 말을 눈을 이이 , 오이  이 전을 나아 이 이 차 한 없고 없었다. “이  이고 이고 이을 말을 이이 이고 말을 내어다 주서 이 거내를 기 다고 그이 사은 사을 사을 비는 이 그 수 내가
# Epoch 15/60
# 3389/3389 [==============================] - 29s 9ms/step - loss: 2.7611
#
# ----- Generating text after Epoch: 14
# ----- Generating with seed: "고 남편을 졸랐다. “이런 오라질 년! 조밥도 못 먹는 년이 설렁탕은. "
# 고 남편을 졸랐다. “이런 오라질 년! 조밥도 못 먹는 년이 설렁탕은. “으로 그 어는 대 하를 김첨지는 대에 벌이 전어라 듯은 내 하고 손나 하며 제 이 근 가 소리가 궂 어의 전하고 그 보장 정생 사 무 한 나 전고 없 “ 로 전 기 하고 손 하고  하고 제 하고 자리라전 말이 야 하는 그 하는 물라고  인력. 나 아 고 전 한 웃 이 말을 전 하고 제 김첨지는 눈에 벌라고 왜 나의 걸 하고 김첨지는 대에 찔지리가 붙 하였다. “하고 급는 는 이 듯었 더, 타 나 . 하고 눈을 전 행리. 하하였다. 그 불는 대의 소리를 구 하고 타 하는 내가 치는 두을 소리리 나까다. “아 야 라의 내 오기  이 전 다. 그 그 집는 게 “으로 얼이 있다. 그 하고 생의 소리들 주 같은 전 하고 걸음에 근어나 그 하을 바어시는 김첨지는 눈은 소리고 나 다. 그 라 운 두 사굴은 바 가 거는
# Epoch 16/60
# 3389/3389 [==============================] - 29s 9ms/step - loss: 2.5542
#
# ----- Generating text after Epoch: 15
# ----- Generating with seed: "장에서 조금 떨어져서 사람 다니는 길과 전찻길 틈에 인력거를 세워 놓고,"
# 장에서 조금 떨어져서 사람 다니는 길과 전찻길 틈에 인력거를 세워 놓고, 하는 소리 이  더 더 가 그 없에 소리가 나어이 같 이 손 없 소리가 속지 이  기  기 운 없 없 한 기 이 좋 한 잔 한 잔 못 못 한 아 아 치기  기 이 아 말 두 전 로 넘 운 나 기었다. 그 나 안 전 아 아 떨어어 기 이 나 채 전를 그는 술 도 없 한 소리가 그 그의 불이 이 보의  이 이 없 생 넘 이 전 재 잔 기 이 아 하기 기기 기  기  내가 치렇 기  기  기 이 . 무 비 한 잔 아 못 나 이 못 며 전 아 . 잔리는 병아 하한 김첨지는게 “이 같은 같 어 이 걸 아 눈 엉 치를 이 나 따 한 없는 대리 이 같은 문 하고 손자에 붙미에 재 이 . 손 아 없 아 웃 전 지 기 아 를 붙 아 못 그 도 병시  대에 같은 막 없다. 그 그 나 그 벌 잔 아 한 전 없는 그 다는 무거
# Epoch 17/60
# 3389/3389 [==============================] - 30s 9ms/step - loss: 2.3655
#
# ----- Generating text after Epoch: 16
# ----- Generating with seed: " 못하니, 왜 먹지를 못하니……괴상하게도 오늘은 운수가 좋더니만……” 끝"
#  못하니, 왜 먹지를 못하니……괴상하게도 오늘은 운수가 좋더니만……” 끝고 김첨지는 대은 이 어은 마은 내을 벌는 말을 지며 웃을 사을 여을 듯이 누서 가을 내려서 그러 이 자리을 다은 김첨지는 눈은 벌 어어한 인력 내 터 늘은 전을 맞우며 차론 이 사을 듯이 치을 얼을 또 지는 걸은 . 에는 걸지 소리리는 어망 다리 자을 그 다리가 어찌 오을 내을 친 하고 사생 이 치기 전은 듯이 그 말을 생아어 그러 기 내 비을 내을 그 렁을 웃러다. 그기가 의 이 없은 오을 듯우 남서 의 아시한 울인 이 나, 듯이 김첨지의 눈은 왜을 먹을 울며 제 집이 눈은 ?이 그 지을 눈을 벌 하고 손 에을 막 에는 걸 근았다. “장장에서 두 이 아을 맞을 없는 오이 있다. 주러 이의 사은 이 그 그리니 화은 병이 김첨지의 코은 얼이 먹을 또 다시 두 기을 내려 끓을 사려 이 나가 바은 제을 대을 웃
# Epoch 18/60
# 3389/3389 [==============================] - 29s 9ms/step - loss: 2.0893
#
# ----- Generating text after Epoch: 17
# ----- Generating with seed: " 하는 짓이 너무 더럽다는 듯이 고개를 소스라치자 더욱 성을 내며, “봐"
#  하는 짓이 너무 더럽다는 듯이 고개를 소스라치자 더욱 성을 내며, “봐이 말말 이, 오리을 나게 듯이 추기를 듯밥 남리 고 오수리 내리 병다. 주리 는 나시시시한 오기을 마자 하는 눈이 게 나리리는 이 하였다. “리가 김첨지는 대시 지를 내리에 서 하는 내리에 치물 마리를 온 하였다. “음 김첨지는 대한 지는 두이 김첨지의 눈리 전하였다. 주리가 의 소리가 어기 더시 시한 하고 오리에게 물르 다리 이 손을 전대. 나리을 입이 전에 울리? 그 손리에 한 하리다. “마장 달 사기 내리  무 거를 또 하고 누리에 대음 치리에 어려 제리가 소리리 어디 듯한 내리를 다는 더이 김첨지는게 오리를 나는 듯이 벌서 또 지굴 대신 일리에 오리리는 “이 전은 맞리에게 “리 다. 전리은 들리을 어벅 하고 사기에 그리 일리이 . 하리는 기 하였다. “장 원는 소리를 나지 말이 마음을 나리 는다.
# Epoch 19/60
# 3389/3389 [==============================] - 25s 8ms/step - loss: 1.8458
#
# ----- Generating text after Epoch: 18
# ----- Generating with seed: " 관대한 어린 손님은 그런 말을 남기고 총총히 옷도 입고 짐도 챙기러 갈"
#  관대한 어린 손님은 그런 말을 남기고 총총히 옷도 입고 짐도 챙기러 갈 더었다. 그 나고 추기 가 도 잔 운으로 제 하였다. 그 가 비음 두 은 잔 기기를 술 아니니, 그 그 말교을 그 나기도 못 오었다. 그 나음 두의 비고 얼서 제 지의 있에다. “어어 음음 마려 얼기 말을 눈금 더려 더서 정여 남을 추교 듯고 웃음다. 궂음 그의 두려에는 걸인 소리가 같은 듯이 내서 내아 웃음 더집에 손인 얼었다. 제 그 나의 두우우 도 잔의 대지 불거의 내은 정의 김첨지의 눈엉 지는 웃을 내려. 돈 치기 소리가 나 그의 기르 길 니기다. 그리나 남음이 집에 으려 제 지 한 모십 전가 있다. 그 나의 걸음 웃음 제 얼기  기 성니 내서 여자 여기 웃음은 듯이 말었다. “설어 두음 두려 웃은 제 인 못한 전은 더려 제 나의 웃에 여려나 정은 제 없음 웃음 정리를 붙으며 어인 남 어 한 손을
# Epoch 20/60
# 3389/3389 [==============================] - 26s 8ms/step - loss: 1.5872
#
# ----- Generating text after Epoch: 19
# ----- Generating with seed: "이도 없이 주정꾼은 목청을 있는 대로 다 내어 호통을 쳤다. “이 오라질"
# 이도 없이 주정꾼은 목청을 있는 대로 다 내어 호통을 쳤다. “이 오라질 가 만만 운이시. 그 보음 남이 우 손을 대어. 그 근어도 한 치를 벌아니, 더 보어. 이 하고 운을 벌지 웃을다. 그 나 그 이 아운은 들어서 붙어어지며 남는 이 진 치는 대에에 어찌어력한 한 그 그릇에 그 나을 대워하는 제 말을 대이 치음을 듯는 치지에 한 오양을 한 그릇 마이 치 지의 대에 지 할 한 벌릇에 그 나을 대한 치지도 못아다. 정왜 사다가 이 잔 은 못운을 없대 수지는 한 나식 대에 먹지를 숭아 수 또 잔다. 그 보은 또 하고 제 어서 웃한 전 채 한 그릇을 그 그 잔릇을 나는 무시한 한 잔의 대에에 거개어여는” 하고 김첨지는 소리가 없러어 지는 게어지 같은 . 모것 그도 얼은은 .” 하지는 뒤경 주 어시한 치 한 잔교 제 한 한 치대한 전 에 그는 가” 하고 손을 얼우다. “여이 사가 남
# Epoch 21/60
# 3389/3389 [==============================] - 26s 8ms/step - loss: 1.2500
#
# ----- Generating text after Epoch: 20
# ----- Generating with seed: "뻤다. 제 자식뻘밖에 안 되는 어린 손님에게 몇번 허리를 굽히며, “안녕"
# 뻤다. 제 자식뻘밖에 안 되는 어린 손님에게 몇번 허리를 굽히며, “안녕 아라이 , 것을 전이 그 거을 맞아 그리에 -진 그 다잎 그리에게도 인력다. “이 사을 전아 이이.,”” 가 말을 맞아 웃고 얼다다. 그리 김첨지는 눈에서 어어어며 다다. 그는 그의 남에 사를 얼무서 한 적다. 김첨지는 대에 섰를 웃이다. “마간 두달 사은 내아가 그 한 한네하고 김첨지의 눈에 찔리에 거다다. 그리 그러 두으으, 얼는 말이 , 병이 맞에서 딱에 치아다. “빼딸 두 말으로, “이보 말이 . 그 아, 전에서 돈시 제다. 이리를 그러 굴을 제 아의 눈에서 마깨 다다. 그리 함을 마려 제 아의 맞아 김첨지는 채꾸 이리에 뒤음 또이 그 한 소리에 어까 의이다. 오리고 그러게 아은 맞아. 이 아… 비이 이 넘을 맞아 그리에 오진오 이 양으로,,”” 그리, 김첨지는 잠리간는 더 나게 그 불의 내가 내
# Epoch 22/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 0.9896
#
# ----- Generating text after Epoch: 21
# ----- Generating with seed: "으로 쏟아져 나왔다. 그 중에서 손님을 물색하던 김첨지의 눈에 양머리에 "
# 으로 쏟아져 나왔다. 그 중에서 손님을 물색하던 김첨지의 눈에 양머리에 다여 높어 시한 정을 내려, 듯이 치 일의 내에 서는 .이 이서 더메 여음 내줄 훌을 울다. 달음이는 다시으이 내가 그다. 제 하고 원이 벌리를 돈 새의 내가 적어터. 그 오어질 가으로 손을 전어한 있었다. 주마지 의 전의 사은 터 랍시. 한 보을 못아아마, 제 아의 눈이 비를 내리치 이 놓깔 내내가 돈 거리가는 이 놈어. 이 아말을 왜아나지는 듯이로 내가 으며 제 이 . 전리가 그 병의 전에 서 터의 내이 비 떨리가며, “어어 이 아 한 소리질 그 거으로 바 아는 가아 이를 내아다. “이 사어 전으으. 제는 붙이 전은 . 치여서 비아 비 터 이 오라질 , 근 수리가 아 한 손기에 한 근르을 대대슬 수 가기질 내가 나서 듯한 정내리는는 오늘은 내가 지랄 가릴 내어 내은다. 전는 원이 전려으. 무죽락 이 전으
# Epoch 23/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 0.7239
#
# ----- Generating text after Epoch: 22
# ----- Generating with seed: "이윽고 끄는 이의 다리는 무거워졌다. 자기 집 가까이 다다른 까닭이다. "
# 이윽고 끄는 이의 다리는 무거워졌다. 자기 집 가까이 다다른 까닭이다. “삼을 운 우면 제다다가 그 도 생을 벌들 오고 추시다. 그 에 그 그 소리에 기 못기의 기 전수 같은 제 내에서 정력 아렸 가 무워한 정릇 전차 가다. 정기 기에 정려 여 얼을 마에 병렇면도 다가 일고 얼을 나를 정여 면도 듯아 하고 정기다. 신음 못하다. “여 불어 있며 이 지묵도 막 적었 가 다기를 기로 두고 맞며 얼굴이 벌었다. 그 그 잔을 소리가 무침 같이 , 그 그세 웃음 가 병여 기를 채 아 도 맞판에 그 있기를 기아 음고 얼다다. 그  어한 얼굴에 기 놓기 내가 ? 그 도 모운 전에에 병찌 기기 기 지면 정증 마음 여 다면  기에 어찌도 말 았니 , 다누 웃고 전기를 정금 남을 사 한 그 그릇에 그 나을 물가 뜨도 못을 왜 금 지며 막아었 . 더시한 신깨 그렁 제도 얼지지 못인다. 그 라 떨어
# Epoch 24/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 0.4868
#
# ----- Generating text after Epoch: 23
# ----- Generating with seed: " 죽일 놈이야.” 하고 김첨지는 엉엉 소리 내어 운다. 치삼은 흥이 조금"
#  죽일 놈이야.” 하고 김첨지는 엉엉 소리 내어 운다. 치삼은 흥이 조금 내이 게서 더의 웃음을 내게 오었다. 그음나, 정다. 자이 사을 전 소리에 어찌 수이 내내당 돈 더 없었다. “압라, 달 떨어 네은 열을 불뜨지 있는 이  같은 내내에 서 더기 일달 조을 내려 여서 더두 듯이 눈내에 울어나게 뒤이 내내 같이 . 하고 추에서 제런 내을 바 아서 정정다. 내가 세일 의 사게도 깊래 수을 왜 내우. 정로 왼 터길 내만 같이 , 얼 거리 만 원높 내한 오렇지게, 구는 자를 전에 게를 귀서 울지나 뒤은 알 내리 웃다다. 그 나 병의 소리 개무 더을 정아 많을 바 당지나 말인이  내어던을 내 아리고 구 죽일 일이 우도 얼마만, “이 , 오라질 내 오라질 말은 이 터개도 할 일었나. 기  시한 정님 하는 추기를 버는 듯이 더 거의게 아푼 어어. 내다라 남이 게을 구는 웃이 추류과게도
# Epoch 25/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 0.3142
#
# ----- Generating text after Epoch: 24
# ----- Generating with seed: ", 빈대떡…….이 너저분하게 늘어 놓은 안주 탁자에 김첨지는 갑자기 속이"
# , 빈대떡…….이 너저분하게 늘어 놓은 안주 탁자에 김첨지는 갑자기 속이 쓰은 이 그 없을 그 그의 그 김첨지의 채 치이 사을 얼 이 한 떨의 벌대이 돈까 이  깔을 길 그의 내리에 넘 더 치 한 어어 제 이 한양적그 그의 물을 이 그의도 그 치기 가기 이  더을 바 었다. 불로 비가 잉  비어 얼서 꿈  마한 내리는 이 떨기로 생 치나 그기 우도 정 진를 내리가 있고 김첨지의 코리 김첨지는 시화 이 김첨지게 대한 마속에 어어오며  한 전을 정작 김첨지는 눈에 벌하였다. “여 이 같십 대은 이 터의 맞판 적 인리 내어!” 하고 김첨지의 눈금 불어터 거 다. 치 이 비면 치기를 돈 그 을 할 수 그 한 없의 그 연제 남기 이 그의 마에 비려 더  많서 마비 치하였다. 그날 그러다. 오늘은 얼이 그 언라이 그 그 소리가 기 를 없이 전을 정이 그 그 떨어에 들어오어어 제 같이 ,
# Epoch 26/60
# 3389/3389 [==============================] - 26s 8ms/step - loss: 0.2137
#
# ----- Generating text after Epoch: 25
# ----- Generating with seed: "섞인 추기가 무딘 김첨지의 코를 찔렀다. 방안에 들어서며 설렁탕을 한구석"
# 섞인 추기가 무딘 김첨지의 코를 찔렀다. 방안에 들어서며 설렁탕을 한구석그리는 이 벌었일가에 그 나, 구 이 벌를 맞아 서 있시. 그 그의 그이 우서 길 지의 맞에 울 안 돈시할 한 그 없을 남가 지는 더이 그 그의 걸은 치이 눈을 얼거거? 는 이시도 한 그 그리 청달 이 무시한 그 그 나릇 막 전 한 모마를 병이 보다. 이 그 잔운에 들 떨어. 기 전 없운다. 그 오일 년이 전 터 일 인 한 전 한 그 그리에 그 그의 물이 그 그의 그리에 없 한 잔를 전에 정려. 뒤 그 한 신의 전에 오기질 무서 길 지 있운 운을 내어?” 김첨지는 눈한 벌를 개여러개  이어. 그 하고 전 하고 손자을 중 에 일 못 잔 전운라 무온 병 무 한 그 신양은 그 그 . 이음 그 전일도 그 나의 못이 적에 돈거거를 호 이본 주이 더 그 한 한본잔 이 그 한 없리 가 병가 가 일 있었다. 그 나어서 이
# Epoch 27/60
# 3389/3389 [==============================] - 26s 8ms/step - loss: 0.1536
#
# ----- Generating text after Epoch: 26
# ----- Generating with seed: " 소리와 함께 발길로 누운 이의 다리를 몹시 찼다. 그러나 발길에 채이는"
#  소리와 함께 발길로 누운 이의 다리를 몹시 찼다. 그러나 발길에 채이는 같이 말을 나이 그도 귀을 울 한겠나 그리나 그러그 일기 놓가 그 을 넘긴 전들어. 제는 이의 김첨지는 걸당 주지근 정은 내 대더 그쁨이 그었다. “이 사라 가 안 죽었어네, 왜 그렇, 막 그 벌기기 기기 기시시시한 내가 그렇래 있렁에 기기 이 없시을 내” 그는 말이 나기를 목었 운을 그 그 벌리에 기 그  일 전을 내가 그렇 더에 얼거. 이용 수 같은 내다. 남이 말을 맞게며 그 거가 그운 수줄 그 아여- 진 진 한 한 그릇 그릇 두이 여기를 몹지 처하하였다. 그럴는 의 양려 또 여이  은 전 ?” 그는  이에  기를 기이 같 같정이 채 나 나요가 그 나기을 그 그릇나청 남이  기일 같이 말을 나를 웃는 눈이하게 조오나 에서  어며 그 그  기기 기숙 더 한 나내 대대 수거를 돈” 고하없게도 그 그릇 청
# Epoch 28/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 0.1148
#
# ----- Generating text after Epoch: 27
# ----- Generating with seed: "번에 이런 금액을 불러라도 본 지가 그 얼마만인가! 그러자, 그 돈 벌 "
# 번에 이런 금액을 불러라도 본 지가 그 얼마만인가! 그러자, 그 돈 벌 가기 그 거며 그 생셨에 모아 그 없을 대습 남는 더시도 한 인교을 왜 석을 왜 아라질 못었다. 궂일 사릇 터이  여지 못은 높속에 한른오는을 들어며 그렁 기한 그 멓음을 바었다. 왜 아이 사같은 손렁인 어무 그  내을 술 그 의 모기를 그  남이 못 오의  에 적 어개 내가 그 없며 맞아 그 나잎 듯한 뼈내에 있거만렀 없 어어 그 전까에 그 그 떨리에 오오라의 구 아스 그 비끔에 두아 었다. “대에 급러하게 사개 방둠 그가 그 그 을 한한 그리에 넘까나 기들 남을 내아 그 근더도 그 나교 청증 내내 같거 , 손 을 치는 전왜 근을 내게 그서 불을 울 한음게 한 손을 듯이 그 그의 맞에서 차진 노을 기 아았나 못인 비 에 할 오의 없이 오라질년, 구아 말(가 이 그렇 걸은 적줄 내려 김첨지의 눈자훌 속이 쓰
# Epoch 29/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 0.1773
#
# ----- Generating text after Epoch: 28
# ----- Generating with seed: " 자기를 노려보는 듯하였다. 그러자 엉엉 하고 우는 개똥이의 곡성도 들은"
#  자기를 노려보는 듯하였다. 그러자 엉엉 하고 우는 개똥이의 곡성도 들은 눈을 듯아 김첨지의게다채 치는 이을 듯 거고 보여 성의 개이 까 지의 내다. 온 김첨지는 원화를 보칵 웃이, “그 , 맞의 벌에 제 터의 걸에 적로 전은 또 웠셨의 두 하는 누렇지는 오라거, 구 그고 남이 놈도 그 지고 그다. 온 에 거물 전을 나아 왜도 게이다. 그리가 집이 나, 제 아고 적서 적내에 거리를 잊지 듯이 . “잎오 두다. 나나 길의 내려 얼서 내이- 거거 가는 듯람 알 그 후를 듯이 게 거거의 채았운 나가 야 한의 적에 전하였다. 주득 창이 다려를 머리에 어디하였다. 달리지을 막다. “대라 사이 전 무을 눈에 쥔하고 불음에 다들 가 없시한 내리 김첨지의 코 불라는 안 못게 가  웃도 못 었었. 이 로 세 가 그 병을 맞가 먹서 놓쩌를 -망 듯이 눈달을 나르는 정이 불을 듯이 김첨지의게 채리
# Epoch 30/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 0.0311
#
# ----- Generating text after Epoch: 29
# ----- Generating with seed: ", “여보게 또 붓다니, 벌써 우리가 넉 잔씩 먹었네. 돈이 사십 전일세"
# , “여보게 또 붓다니, 벌써 우리가 넉 잔씩 먹었네. 돈이 사십 전일세. 그리가 집에  어사을 듯한 적을 비게 오음 얼이 . 그빼도 그 하고 누달 섞를 내아으니 더 조어 짓생 워 고 바었다. “왜 사근 남이 얼죽단 못인  속 같 절도 눈을 비아 여리에 게 오의 운 전 줄 모기를 왜 말을 맞 왔면 내가 로 먹의 듯이 문 하고 맞음 높의 소리에 몹 새찼 내 전 나그 기무 더 진 일본 그 원 한 에 벌릇 그 렁을 물물든 그 더 일기에 집은 붙아 있거 , 손에 굶에 울을 내려 내서 얼을 비를 듯아 김첨지는게 아었 주리가 웃음다. 그 근 그러나 채 인 한 아의 맞에 적는 있이다. 그리가 집는  이 사 를 숭양은 못하였다. 그러자는 두의 소리가 어찌 기을 왜 김첨지의 코채 찔이보. 뒤다. 김첨지는 어경 섰에 전나화타 엇 로 연운 그릇 제차에 거설나 나었 . 손에서 정그 불 비 두기를 기
# Epoch 31/60
# 3389/3389 [==============================] - 26s 8ms/step - loss: 0.0083
#
# ----- Generating text after Epoch: 30
# ----- Generating with seed: "못하고 천정만 바라보느냐, 응” 하는 말끝엔 목이 메이었다. 그러자 산 "
# 못하고 천정만 바라보느냐, 응” 하는 말끝엔 목이 메이었다. 그러자 산 사교 치은 얼는  아지 못한 성벼에 돈른 르어  집에 그망 오리  음 손 내가 자이 김첨지의 눈채를 찔보어 어어하였다. 달아은 비가 소리가 치 비기 추한 적을 내려 여는 더이 성 거리에 또 어어 어어 제 내리. 그 비가 비이  려에 얼기 여 없의 적에서 마하고 . 하고  는 근게 웃를 맞 얼 거를 듯아  깔 추을 내려 치리더더 다았 높  개 으다. 그 그 에 병의 대은 차 간기을 기털 김첨지의 코 훌는 보이 성 내 가 에 한 나  전에 내려 터이 . 일에  에 치 떨내 내어 제 병의 맞에 전 나겠도 듯니 그 구잎 소리가 그 그 의 생 줄 벌릇 그 그 있에에 기염 수 아일 내에 그 더리에는다. 그리에 집 하의 제 병라질 기로 이 말 도 오제 그 떨의 마에  오 의 판양으 어른 제 에 있거도 마치 이의 오리에
# Epoch 32/60
# 3389/3389 [==============================] - 27s 8ms/step - loss: 0.1677
#
# ----- Generating text after Epoch: 31
# ----- Generating with seed: " 어린 손님은 그런 말을 남기고 총총히 옷도 입고 짐도 챙기러 갈 데로 "
#  어린 손님은 그런 말을 남기고 총총히 옷도 입고 짐도 챙기러 갈 데로 듯이 돈 거를 맞아 놓이 . 오하던 바자이 어어어 마하였다. 그렇 은의 다리 여 비을 맞아 수 더 거리를 나들 비어어, 하다. 그는 김첨지는 코화 같지 성은 내 서
