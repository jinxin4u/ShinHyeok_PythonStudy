# %%
# LINUX : mariaDB, 서버관리자

# - 서비스 제공을 제어 : systemctl
#     systemctl get-default : graphic mode / text mode
# - 보안 : firewall-cmd - firewall 방화벽

# firewall-cmd --permanent --zone=public --add-port=3306/tcp

# HeidiSQL : 원격으로 mariaDB접속 작업

    
    
#           원격
# MS        ->    Cent OS
# HideiSQL  ->    mariaDB


# vi 편집기
# - 명령모드 : esc
#     dd : 삭제, yy : 복사, p : 붙여넣기

# - 입력모드 i,a,o
#     i

# - 마지막행 모드
#     w : 저장, q : 종료, q! : 저장하지않고 종료


필요 유틸
- oracle VM windows host package,
- vm extension pack
- Cent OS 7
- HeidiSQL
- putty


* 가상머신 설치 세팅
리눅스 other linux 64bit
가상머신 메모리 4096
공간 30기가 쯤 잡아줘라
설정

저장소 센트os cd 저장소

소프트웨어 선택
    - 서버GUI
       체크항목 : FTP서버, 마리아디비, postgreSQL, 호환성, 개발툴,보안툴,시스템 관리
        
루트 암호 설정
    - pw : acorn1234Q!
        
        
        

라이센스 동의해주고
네트워크 이더넷 켜주고
설정완료        

사용자정보 jeju
비번은 아까쓰던거 쓰고



터미널 켜서뇬ㅅ
systemctl get-default
systemctl set-default multi-user.target     
비번인증해주고
reboot


새로실행해서 로그인해줘

ifconfig
startx 치면 gui모드로..


        
명령어
#현재모드 알려줌
systemctl get-default
# 멀티유저타겟의 시스템 설정 -> 텍스트 모드로 변경되어 설정내용확인
systemctl set-default multi-user.target

reboot
shutdown -h now # 즉시 셧다운
ps -ef # 현재 메모리 실행되는 내용 확인

cd # change directory
mkdir # make directory
rmdir # remove directory
cd ~ # 루트 디렉토리로
cp  # copy
rm  # remove
find / -name test.txt -print # test.txt라는 이름의 파일을 찾아서 프린트해라

vi # 명령행모드, 입력모드, 실행명령(커맨드)
# 명령행모드
#    - dd 삭제, yy 복사, p 붙여넣기
# 입력모드
#    - i insert, a append, o
# 실행명령
#    - :q 종료, w저장, q!저장하지 않고 종료

yum 패키지 설치
 rpm을 래퍼
    ex) 마리아 디비 설치
     yum install maria-server

# 서버관리하기위해서 (텍스트 모드로 작업)

systemctl 서비스를 제어
firewall-cmd 방화벽
systemctl start mariadb # 마리아db실행
systemctl stop mariadb # 마리아db종료
systemctl restart mariadb # 설정 변경 시에 마리아db 재실행 해주면 된다

ps -ef | grep httpd # 웹서버가 메모리상에 상주되어 켜져있는지 확인
#grep은 검색 명령








마리아DB 윈도우환경에서 쓰자!
https://mariadb.org/
    
mariadb 10.4.11

네트워크에서 root조회 가능 체크
utf 체크



varchar 가변형 문자열
